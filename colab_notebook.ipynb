# %%
# !git clone https://github.com/EmertonData/robotics.git
# Out:
# Cloning into 'robotics'...
# remote: Enumerating objects: 504, done.
# remote: Counting objects: 100% (504/504), done.
# remote: Compressing objects: 100% (443/443), done.
# remote: Total 504 (delta 109), reused 421 (delta 49), pack-reused 0 (from 0)
# Receiving objects: 100% (504/504), 12.86 MiB | 18.39 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
# %cd robotics
# Out:
# /content/robotics

# %%
# %env HF_LEROBOT_HOME=/content/drive/MyDrive/Hackathon/datasets
# Out:
# env: HF_LEROBOT_HOME=/content/drive/MyDrive/Hackathon/datasets

# %% [markdown]
# After running this cell, colab will ask to restart the session, just run the entire notebook again.

# %%
# !pip install -e '.[feetech]'
# Out:
# Obtaining file:///content/robotics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.1.0-py3-none-any.whl size=15029 sha256=73bb8f3b4610d9112be1264b5212f50e933d4339c871255090d40ef4d6a1e4aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ar2htyao/wheels/e0/2e/76/b8a6f6594d24016d293d7c0f1fde20e235674ed1e113499851
# Successfully built lerobot
# ...
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.1.0
#     Uninstalling lerobot-0.1.0:
#       Successfully uninstalled lerobot-0.1.0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install flash-attn --no-build-isolation
#%env USE_FLASH_ATTENTION=1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 51.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for flash-attn: filename=flash_attn-2.7.4.post1-cp311-cp311-linux_x86_64.whl size=187831595 sha256=58853b28a5a926cae14402bfd8d4d93a45ebf8f9e79533f37ab09d0d77a99c05
#   Stored in directory: /root/.cache/pip/wheels/3d/88/d8/284b89f56af7d5bf366b10d6b8e251ac8a7c7bf3f04203fb4f
# Successfully built flash-attn
# ...
# env: USE_FLASH_ATTENTION=1

# %%
#%env TORCH_COMPILE=1
#%env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Out:
# env: TORCH_COMPILE=1
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
# %env HF_USER=your_username
# Out:
# env: HF_USER=your_username

# %%
# !echo $HF_USER
# Out:
# your_username

# %%
# !python lerobot/scripts/train.py \
  --dataset.repo_id=${HF_USER}/so100_test \
  --policy.type=act \
  --output_dir=../drive/MyDrive/Hackathon/datasets/outputs/train/${HF_USER}_act_so100_b8_lr1e5_2 \
  --job_name=${HF_USER}_act_so100_b8_lr1e5 \
  --device=cuda \
  --wandb.enable=true
# Out:
# /content/drive/MyDrive/Hackathon/datasets
# INFO 2025-03-18 15:27:00 ts/train.py:111 {'batch_size': 8,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
# ...
